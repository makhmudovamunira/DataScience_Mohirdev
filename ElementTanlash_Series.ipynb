# %% [markdown]
# <a href="https://colab.research.google.com/github/makhmudovamunira/DataScience_Mohirdev/blob/main/ElementTanlash_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
series=df['calories']
series
# Out:
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
v=series[1]
v
# Out:
# 380

# %%
type(v)
# Out:
# numpy.int64

# %%
series[[1]]
# Out:
# 1    380
# Name: calories, dtype: int64

# %%
type(series[[2]])
# Out:
# pandas.core.series.Series

# %%
obj=pd.Series(np.arange(8.),index=['a','b','c','d','e','f','h','g'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# h    6.0
# g    7.0
# dtype: float64

# %%
obj['a']
# Out:
# 0.0

# %%
obj[obj>5]
# Out:
# h    6.0
# g    7.0
# dtype: float64

# %%
obj1=pd.Series(np.arange(8.),index=['10','11','13','14','15','16','17','18'])
obj1
# Out:
# 10    0.0
# 11    1.0
# 13    2.0
# 14    3.0
# 15    4.0
# 16    5.0
# 17    6.0
# 18    7.0
# dtype: float64

# %%
obj1['18']
# Out:
# 7.0
