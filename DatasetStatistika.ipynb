# %% [markdown]
# <a href="https://colab.research.google.com/github/makhmudovamunira/DataScience_Mohirdev/blob/main/DatasetStatistika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni','aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum()
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2.head()
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317

# %%
df2.sum()
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
df.max()
# Out:
# maydoni     160000.0
# aholisi    4450000.0
# dtype: float64

# %%
df.idxmax()
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
df['maydoni'].argmax()
# Out:
# 8

# %%
df['aholisi'].argmin()
# Out:
# 10

# %%
df2
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317
# Gentra  30368  26266

# %%
df2.idxmax()
# Out:
# 2020    Cobalt
# 2021    Cobalt
# dtype: object

# %%
df2.idxmin()
# Out:
# 2020     Labo
# 2021    Spark
# dtype: object

# %%
df2.min()
# Out:
# 2020    4521
# 2021    6485
# dtype: int64

# %%
print(df['aholisi'].idxmax(), 'aholisi', df['aholisi'].max())
# Out:
# Toshkent viloyati aholisi 4450000.0

# %%
print(df['maydoni'].idxmax())
print(df['maydoni'].max())
# Out:
# Qoraqalpogʻiston Respublikasi
# 160000.0

# %% [markdown]
# ## Boshqa funksiyalar
#
# `count` - NaN bo'lmagan qiymatlar soni
#
# `median` - qiymatlar medianini hisbolash
#
# `mad` - mean absolute deviation
#
# `prod` - barcha qiymatlar ko'paytmasi
#
# `var` - variance (dispersiya)
#
# `std` - standart deviation (standart chetlanis)
#
# `skew` - skewness
#
# `kurt` - kurtosis
#
# `cumsum` - cumulative sum
#
# `cummin` va `cummax`- cumulative min and max
#
# `cumprod` - cumulative product
#
# `diff` - arifmetik farq (difference)
#
# `pct_change` - percent changes

# %%
df.count()
# Out:
# maydoni    13
# aholisi    13
# dtype: int64

# %%
df.median()
# Out:
# maydoni      16400.0
# aholisi    1676000.0
# dtype: float64

# %%
df2.prod()
# Out:
# 2020      61887297365967808
# 2021    9151971529123863600
# dtype: int64

# %%
df.var()
# Out:
# maydoni    2.230191e+09
# aholisi    1.006033e+12
# dtype: float64

# %%
df.skew()
# Out:
# maydoni    2.176391
# aholisi    1.629809
# dtype: float64

# %%
df.kurt()
# Out:
# maydoni    4.119613
# aholisi    3.681670
# dtype: float64

# %%
df.cumsum()
# Out:
#                                 maydoni     aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0   1899000.0
# Buxoro viloyati                 43600.0   3283700.0
# Fargʻona viloyati               50400.0   5880700.0
# Jizzax viloyati                 70900.0   6791200.0
# Xorazm viloyati                 77200.0   7991200.0
# Namangan viloyati               85100.0   9853200.0
# Navoiy viloyati                195900.0  10620700.0
# Qashqadaryo viloyati           224300.0  12649700.0
# Qoraqalpogʻiston Respublikasi  384300.0  13849700.0
# Samarqand viloyati             400700.0  16171700.0
# Sirdaryo viloyati              405800.0  16819800.0
# Surxondaryo viloyati           426600.0  18495800.0
# Toshkent viloyati              441900.0  22945800.0

# %%
df.cummin()
# Out:
#                                maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                4200.0  1899000.0
# Buxoro viloyati                 4200.0  1384700.0
# Fargʻona viloyati               4200.0  1384700.0
# Jizzax viloyati                 4200.0   910500.0
# Xorazm viloyati                 4200.0   910500.0
# Namangan viloyati               4200.0   910500.0
# Navoiy viloyati                 4200.0   767500.0
# Qashqadaryo viloyati            4200.0   767500.0
# Qoraqalpogʻiston Respublikasi   4200.0   767500.0
# Samarqand viloyati              4200.0   767500.0
# Sirdaryo viloyati               4200.0   648100.0
# Surxondaryo viloyati            4200.0   648100.0
# Toshkent viloyati               4200.0   648100.0

# %%
df.cummax()
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1899000.0
# Fargʻona viloyati               39400.0  2597000.0
# Jizzax viloyati                 39400.0  2597000.0
# Xorazm viloyati                 39400.0  2597000.0
# Namangan viloyati               39400.0  2597000.0
# Navoiy viloyati                110800.0  2597000.0
# Qashqadaryo viloyati           110800.0  2597000.0
# Qoraqalpogʻiston Respublikasi  160000.0  2597000.0
# Samarqand viloyati             160000.0  2597000.0
# Sirdaryo viloyati              160000.0  2597000.0
# Surxondaryo viloyati           160000.0  2597000.0
# Toshkent viloyati              160000.0  4450000.0

# %%
df.cumprod()
# Out:
#                                     maydoni       aholisi
# Boʻlinishi
# Andijon viloyati               4.200000e+03  1.899000e+06
# Buxoro viloyati                1.654800e+08  2.629545e+12
# Fargʻona viloyati              1.125264e+12  6.828929e+18
# Jizzax viloyati                2.306791e+16  6.217740e+24
# Xorazm viloyati                1.453278e+20  7.461288e+30
# Namangan viloyati              1.148090e+24  1.389292e+37
# Navoiy viloyati                1.272084e+29  1.066281e+43
# Qashqadaryo viloyati           3.612718e+33  2.163485e+49
# Qoraqalpogʻiston Respublikasi  5.780348e+38  2.596182e+55
# Samarqand viloyati             9.479771e+42  6.028335e+61
# Sirdaryo viloyati              4.834683e+46  3.906964e+67
# Surxondaryo viloyati           1.005614e+51  6.548071e+73
# Toshkent viloyati              1.538590e+55  2.913892e+80

# %%
df.diff()
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                    NaN        NaN
# Buxoro viloyati                 35200.0  -514300.0
# Fargʻona viloyati              -32600.0  1212300.0
# Jizzax viloyati                 13700.0 -1686500.0
# Xorazm viloyati                -14200.0   289500.0
# Namangan viloyati                1600.0   662000.0
# Navoiy viloyati                102900.0 -1094500.0
# Qashqadaryo viloyati           -82400.0  1261500.0
# Qoraqalpogʻiston Respublikasi  131600.0  -829000.0
# Samarqand viloyati            -143600.0  1122000.0
# Sirdaryo viloyati              -11300.0 -1673900.0
# Surxondaryo viloyati            15700.0  1027900.0
# Toshkent viloyati               -5500.0  2774000.0

# %%
df.pct_change()
# Out:
#                                  maydoni   aholisi
# Boʻlinishi
# Andijon viloyati                     NaN       NaN
# Buxoro viloyati                 8.380952 -0.270827
# Fargʻona viloyati              -0.827411  0.875496
# Jizzax viloyati                 2.014706 -0.649403
# Xorazm viloyati                -0.692683  0.317957
# Namangan viloyati               0.253968  0.551667
# Navoiy viloyati                13.025316 -0.587809
# Qashqadaryo viloyati           -0.743682  1.643648
# Qoraqalpogʻiston Respublikasi   4.633803 -0.408576
# Samarqand viloyati             -0.897500  0.935000
# Sirdaryo viloyati              -0.689024 -0.720887
# Surxondaryo viloyati            3.078431  1.586021
# Toshkent viloyati              -0.264423  1.655131
