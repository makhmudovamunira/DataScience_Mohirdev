# %% [markdown]
# <a href="https://colab.research.google.com/github/makhmudovamunira/DataScience_Mohirdev/blob/main/Copy_of_04_VISUAL_AMALIYOT_02_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 2-AMALIYOT. `seaborn`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1-VAZIFA. Avvalgi [amaliyotda](https://colab.research.google.com/drive/1jzhJ1gN6msILYOHaG2fhBBvUGaa4tcLf?usp=sharing) saqlangan faylni yangi `df`ga o'qing

# %%
#JAVOBINGIZNI SHU YERGA YOZING
df=pd.read_csv('/content/Toshkent_harorat.csv')
df.head()
# Out:
#    Year     T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# 0  1990  14.9  21.5  8.7  504.72  5.1  84  32  12  12  0  1
# 1  1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 2  1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 3  1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 4  1994  14.4  21.1    8  595.38  5.1  66  28   4   9  0  0

# %%
df=df.set_index('Year')
df.head()
# Out:
#          T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# Year
# 1990  14.9  21.5  8.7  504.72  5.1  84  32  12  12  0  1
# 1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 1994  14.4  21.1    8  595.38  5.1  66  28   4   9  0  0

# %%
#@title Misol:
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %% [markdown]
# ### 2-VAZIFA. `df` barcha ustunlarini chiziqli grafik ko'rinishida chiqaring

# %%
df.fillna(method='bfill',axis=1, inplace=True)
df.head()
# Out:
# <ipython-input-35-d4c0144cb119>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',axis=1, inplace=True)
#          T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# Year
# 1990  14.9  21.5  8.7  504.72  5.1  84  32  12  12  0  1
# 1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 1994  14.4  21.1    8  595.38  5.1  66  28   4   9  0  0

# %%
values={'T':14,'TM':20,'Tm':8,'PP':504,'V':5,'RA':60,'SN':28,'TS':12,'FG':10,'TN':0.5,'GR':1}
df.replace('-', values, inplace=True)
df
# Out:
#          T    TM    Tm      PP    V   RA  SN  TS  FG   TN GR
# Year
# 1990  14.9  21.5   8.7  504.72  5.1   84  32  12  12    0  1
# 1991  14.4  21.2   8.3  460.52  5.1   77  26  15  17    0  1
# 1992  14.4  20.8   8.6  470.39  5.1   93  19   9   2    0  1
# 1993  13.4  19.6   7.6  710.97  5.4   98  38  12  10    1  0
# 1994  14.4  21.1     8  595.38  5.1   66  28   4   9    0  0
# 1995    15  22.2   8.4  189.99  4.4   41  20   8  12    0  0
# 1996    14  20.5   7.6  184.16    5   68  23  14  13    0  0
# 1997    14    20     8     504    5   60  28  12  10  0.5  1
# 1998    14    20     8     504    5   60  28  12  10  0.5  1
# 1999  15.7  22.4   8.9  524.21  7.6   98  15  13  18    0  0
# 2000    16  22.5   9.1     504    8   84  19  11  25    0  2
# 2001  16.3  22.7   9.2     504  8.2   80  20  12  23    1  0
# 2002    14    20     8     504    5   92  35  13  28    0  0
# 2003  15.6  21.7   8.9  564.92  7.8  109  22  13  19    0  1
# 2004  16.6  22.8   9.6  410.74  7.7  104  17   7  34    0  0
# 2005    14    20     8     504    5   60  28  12  10  0.5  1
# 2006  16.4  22.6     9     504  9.1   93  29  21  44    0  0
# 2007  16.2  22.6   8.5     504    9   86  17  16  37    0  0
# 2008  15.9  22.3   8.4     504  8.8   75  34   7  45    0  3
# 2009  16.1  22.3   8.7     504    9  119  12  22  31    0  1
# 2010  16.8  23.3   9.4     504    9  109  13  27  27    0  0
# 2011  15.8  21.8   8.6     504  9.5  105  41  16  50    0  0
# 2012    15  21.4   7.9     504  9.4   86  40  23  28    0  2
# 2013  16.3  22.6   9.1     504  9.6   90  29  17  22    0  0
# 2014  14.9  21.2   7.8     504  9.5   96  30  13  34    0  2
# 2015  16.3  22.3   9.6     504  9.9  119  23  19  14    0  0
# 2016  16.8  23.3   9.9     504  9.9  102  24  11   6    0  0
# 2017    16  22.3     9     504  9.9   92  27  14  31    0  0
# 2018    16  22.4   9.3     504  9.7   92  16   9  30    0  0
# 2019  16.6  22.5    10     504  9.8  111  16  12  19    0  0
# 2020  15.5  21.3   9.2     504  9.8   92  37  18  26    0  0
# 2021    17  23.4  10.1     504   10   82  11  10  14    0  0
# 2022  16.7  22.6  10.2     504  9.8  115  17  14  32    0  0
# 2023  17.3  23.6  10.4     504   10   96  15  14  19    0  0
# 2024    14    20     8     504    5   60  28  12  10  0.5  1

# %%
df=df.apply(pd.to_numeric, errors='coerce')
type(df.loc[2000, 'T'])
# Out:
# numpy.float64

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(12,8))
sns.lineplot(data=df)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel('Yil')
plt.show()

# %%
#@title Javob
plt.figure(figsize=(16,6))
sns.lineplot(data=df)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Grafiklar nomini to'g'rilang (`T`, `Tm` va hokazo matnlarni o'zbek tilida chiqaring.)

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(12,6))
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar"]
sns.lineplot(data=df, linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df, linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 4-VAZIFA. Yuqoridagi grafikda turli ko'rsatkichlar aralashib ketdi. Keling ustun turiga qarab alohida grafiklar chizamiz.
#
# #### 4.1. Haroratni ko'rsatuvchi ustunlarni alohida chiziqli grafik qilib chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat"]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['T','TM','Tm']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        # "Yomg'irli kunlar soni",
        # "Bo'ronli kunlar soni",
        # "Tumanli kunlar soni",
        # "To'fonli kunlar soni",
        # "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['T','TM','Tm']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# #### 4.2. Kunlarni ko'rsatuvchi ustunlarni alohida grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
labels=["Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar"]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['RA','SN','TS','FG','TN']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %%
#@title Kutilgan natija:
labels=[
        # "Yillik o'rtacha harorat",
#         "Yillik o'rtacha maksimal harorat",
#         "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar soni"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['RA','SN','TS','FG','TN']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Kunlar")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. Yillik o'rtacha shamol tezligini ustunli grafik ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(12,6))
sns.barplot(x=df.index, y=df['V'])
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.ylabel("O'rtacha shamol tezligi (km/soat)")
plt.xlabel("Yillar")
plt.xticks(rotation=90)
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(16,6))
sns.barplot(x=df.index, y=df['V'])
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.ylabel("O'rtacha shamol tezligi (km/soat)")
plt.xlabel("Yillar")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 6-VAZIFA. Yomg'rili, qorli, bo'ronli, tumanli va do'l yoqqan kunlar sonini heatmap ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(30,5))
sns.heatmap(data=df[['RA','SN','TS','FG','TN']].T,cmap="YlGnBu", linewidths=1, square=True)
yticks_labels=["Yomg'ir","Qor","Bo'ron","Tuman","Do'l"]
plt.yticks(np.arange(5)+.5, labels=yticks_labels)
plt.xticks(rotation=90)
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(30,5))
sns.heatmap(data=df[['RA','SN','TS','FG','GR']].T, cmap="YlGnBu", linewidths=1, square=True)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
yticks_labels = ["Yomg'ir","Qor","Bo'ron","Tuman","Do'l"]
plt.yticks(np.arange(5)+0.5, labels=yticks_labels)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
